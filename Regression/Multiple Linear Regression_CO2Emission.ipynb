# %% [markdown]
# # <center> Multiple Linear Regression on CO2 Emissions : Core Logic Approach </center>

# %% [markdown]
# ## Importing Dependencies

# %%
import numpy as np
import pandas as pd
import math
import random

# %% [markdown]
# ## Importing the dataset into the environment

# %%
co2Data = pd.read_csv("Datasets/CO2emission.csv") #loading dataset

# %% [markdown]
# ## Inspecting the dataset

# %%
co2Data[:5] # head()
# Out:
#     Make       Model VehicleClass  EngineSize  Cylinders  FuelConsumptionCity  \
# 0  ACURA         ILX      COMPACT         2.0          4                  9.9
# 1  ACURA         ILX      COMPACT         2.4          4                 11.2
# 2  ACURA  ILX HYBRID      COMPACT         1.5          4                  6.0
# 3  ACURA     MDX 4WD  SUV - SMALL         3.5          6                 12.7
# 4  ACURA     RDX AWD  SUV - SMALL         3.5          6                 12.1
#
#    CO2Emissions
# 0           196
# 1           221
# 2           136
# 3           255
# 4           244

# %%
co2Data.shape # (rows, columns)
# Out:
# (7385, 7)

# %%
co2Data.isnull().sum()
# Out:
# Make                   0
# Model                  0
# VehicleClass           0
# EngineSize             0
# Cylinders              0
# FuelConsumptionCity    0
# CO2Emissions           0
# dtype: int64

# %%
co2Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Make                 7385 non-null   object
#  1   Model                7385 non-null   object
#  2   VehicleClass         7385 non-null   object
#  3   EngineSize           7385 non-null   float64
#  4   Cylinders            7385 non-null   int64
#  5   FuelConsumptionCity  7385 non-null   float64
#  6   CO2Emissions         7385 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 404.0+ KB

# %%
co2Data.describe()
# Out:
#         EngineSize    Cylinders  FuelConsumptionCity  CO2Emissions
# count  7385.000000  7385.000000          7385.000000   7385.000000
# mean      3.160068     5.615030            12.556534    250.584699
# std       1.354170     1.828307             3.500274     58.512679
# min       0.900000     3.000000             4.200000     96.000000
# 25%       2.000000     4.000000            10.100000    208.000000
# 50%       3.000000     6.000000            12.100000    246.000000
# 75%       3.700000     6.000000            14.600000    288.000000
# max       8.400000    16.000000            30.600000    522.000000

# %%
co2Data.duplicated().sum() #number of duplicated rows
# Out:
# 1295

# %%
co2Data = co2Data.drop_duplicates() #dropping duplicated rows
co2Data.duplicated().sum() #number of duplicated rows
# Out:
# 0

# %%
co2Data.shape
# Out:
# (6090, 7)

# %%
# Classes within the 'Make' attribute
print("The categories in the column {} are as follows = {}".format("'Make'",set(co2Data.Make)))
print("The count of categories in the column {} = {}".format("'Make'", len(set(co2Data.Make))))
# Out:
# The categories in the column 'Make' are as follows = {'NISSAN', 'PORSCHE', 'CHRYSLER', 'FORD', 'LAND ROVER', 'FIAT', 'KIA', 'DODGE', 'BUGATTI', 'HYUNDAI', 'ASTON MARTIN', 'ACURA', 'SUBARU', 'JAGUAR', 'RAM', 'CHEVROLET', 'ROLLS-ROYCE', 'CADILLAC', 'VOLKSWAGEN', 'BMW', 'BENTLEY', 'AUDI', 'SRT', 'MASERATI', 'GMC', 'LAMBORGHINI', 'HONDA', 'INFINITI', 'MINI', 'SMART', 'TOYOTA', 'JEEP', 'LEXUS', 'SCION', 'ALFA ROMEO', 'VOLVO', 'LINCOLN', 'MERCEDES-BENZ', 'MITSUBISHI', 'GENESIS', 'BUICK', 'MAZDA'}
# The count of categories in the column 'Make' = 42

# %%
# Classes within the 'Model' attribute
print("The count of categories in the column {} = {}".format("'Model'", len(set(co2Data.Model))))
print("The categories in the column {} are as follows = {}".format("'Model'",set(co2Data.Model)))
# Out:
# The count of categories in the column 'Model' = 2053
# The categories in the column 'Model' are as follows = {'SAVANA 2500 PASSENGER', 'Edge', 'SANTA FE SPORT AWD', 'COOPER S ROADSTER', 'Wrangler Unlimited 4X4', '535i xDRIVE SEDAN', 'WRANGLER JK 4X4', 'SAVANA 1500 CARGO CONV', 'Sierra WT', 'AMG GLC 63 S 4MATIC+', 'SILVERADO 4WD FFV', '435i xDRIVE GRAN COUPE', 'STINGER AWD', 'Panamera 4S Executive', 'ProMaster City', '370Z', 'MAZDA6 TURBO', 'XTS AWD', 'Palisade', 'CAYENNE S HYBRID', 'M4 Cabriolet', 'TRANSIT CONNECT WAGON FFV', 'AMG SLC 43', 'GL 63 AMG', 'CRUZE', '911 Carrera 4 Cabriolet', 'Cayenne Turbo', 'S5', 'A4 ALLROAD QUATTRO', 'Range Rover Evoque', 'Macan', 'COOPER S COUPE', 'RANGE ROVER V8 5.0 SC FFV', 'JOHN COOPER WORKS 3 DOOR', 'M5 Sedan', 'Flex AWD GTDI', 'XJ R-Sport AWD', 'XJL PORTFOLIO 3.0 AWD', 'MDX SH-AWD', 'M550i xDrive', 'ACTIVEHYBRID 7L', '911 TURBO S CABRIOLET', 'Traverse AWD', 'AVENGER', 'FORTWO CABRIOLET', 'M240i xDRIVE COUPE', 'Edge AWD', 'iQ', 'AMG CLA 45', 'HURACAN SPYDER AWD', 'TT RS Coupe', 'AMG GLE 63 S COUPE 4MATIC', 'MDX 4WD', 'T-150 Wagon FFV', 'Frontier 4WD', 'COOPER ROADSTER', 'Sierra', 'RANGE ROVER SUPERCHARGED', 'Highlander AWD', 'NIRO TOURING', 'XC40 T5 AWD', 'V60 T5 AWD', 'XV CROSSTREK AWD', 'VIPER SRT', '911 Turbo S', '540i xDrive', 'RIO', 'RANGE ROVER TD6 DIESEL', 'XC40 T4 AWD', 'Alpina B6 xDrive Gran Coupe', 'AMG GT 53 4MATIC+ Coupe', 'KONA', 'LS 500h', 'Outlander 4WD', 'Corolla XSE', 'Metris Cargo LWB', '911 CARRERA 4 GTS CABRIOLET', 'M6 COUPE', 'Charger', 'MX-5', 'SIERRA FFV', 'DB11 V8', 'Range Rover Velar D180', 'FOCUS (Start/Stop)', 'EcoSport AWD', 'Rogue', 'M240i Coupe', 'X7 xDrive40i', 'RANGE ROVER V6 3.0 SC FFV', 'GL 550 4MATIC', 'ALPINA B7 xDRIVE', 'GLS 450 4MATIC', 'Ghibli S', 'X6 M', 'CIVIC TYPE R', 'COROLLA LE ECO (2-mode)', 'ECOSPORT AWD', 'YARIS HATCHBACK', 'S80 AWD', 'CX-5 4WD (Cylinder Deactivation)', 'ACTIVEHYBRID 3', 'PATRIOT 4X4', 'Transit Connect Van', 'F-TYPE R AWD Coupe', 'EXPEDITION 4X4 FFV', 'xD', '500 HATCHBACK TURBO', 'MDX SH-AWD A-SPEC', 'SLS AMG GT ROADSTER', 'GOLF R', 'Sportage', 'Renegade 4X4', 'ES 350 F SPORT', 'Grand Cherokee 4X4', '911 Turbo', 'TERRAIN FFV', 'XF S AWD', 'CONTINENTAL GTC', 'Altima SR/Platinum', 'M5', 'SUBURBAN 4WD', 'Malibu Hybrid', 'JOURNEY AWD', 'F-150 RAPTOR 4WD', 'SANTA FE 4WD', 'CT6', '330i xDrive Touring', 'E 550 4MATIC', 'CRUZE PREMIER', 'A7 QUATTRO', '1500 Classic 4X4', 'GIULIA', 'Yukon XL', '1500 Classic 4X4 FFV', 'E 350 4MATIC', 'ALPINA B7 xDRIVE LWB', 'XJ AWD', 'Tahoe FFV', '300 AWD (MDS)', 'F-150 (Payload Pkg)', 'ATS-V', 'E 400 4MATIC', 'Terrain AWD', 'F-TYPE V8 R COUPE', 'S5 SPORTBACK', 'Charger AWD (MDS)', 'C 350 4MATIC COUPE', 'CLS 63 AMG 4MATIC', 'NV200 Cargo Van', 'Palisade AWD', 'ACCORD SPORT', '330i xDrive Gran Turismo', 'Murano', '550i xDRIVE GRAN TURISMO', 'FR-S', 'LACROSSE eASSIST', 'F-TYPE PROJECT 7 CONVERTIBLE', 'CHALLENGER GT AWD FFV', 'Forte 5', 'Passport AWD', 'Cherokee', 'E 250 BLUETEC 4MATIC', 'LS 460 L AWD', 'AMG GT COUPE', 'X5 M', 'A5 SPORTBACK QUATTRO', '428i CABRIOLET', 'NX 300 AWD F SPORT', 'Santa Fe', 'GRAND CHEROKEE 4X4 FFV', 'AMG GLE 63 S 4MATIC COUPE', 'Micra', 'E-PACE P300', 'TRANSIT CONNECT TAXI', 'NSX', 'CT4-V AWD', 'A 250 4MATIC', 'SLK 300', 'E350 WAGON FFV', 'AMG GLE 43 4MATIC COUPE', '911 TURBO S EXCLUSIVE', 'Beetle Convertible', 'Discovery Sport', 'C 300 4MATIC Wagon', 'XT6 AWD', 'A5 Cabriolet quattro', '300', 'FIESTA ST', 'RS 5 CABRIOLET', 'Beetle Dune Convertible', 'CHEROKEE 4X4 ACTIVE DRIVE LOCK', '300 SRT (MDS)', 'Camry XSE', 'Tiguan', 'S 450 4MATIC SWB', 'A8 QUATTRO TDI (modified)', 'Yukon', '370Z Roadster', 'BOXSTER', 'COOPER S CLUBMAN', 'X4 xDrive30i', 'Cadenza', 'DART', 'Q5 TDI (modified)', 'Z4 sDRIVE35i', 'F-TYPE Convertible R-Dynamic AWD', 'AMG GT S', 'ATLAS 4MOTION', 'V60 POLESTAR AWD', 'ENCLAVE AWD', 'GRAND CHEROKEE 4X4 SRT', 'S 560 CABRIOLET', 'IS 350', 'Golf', 'Corolla', 'Q5 QUATTRO TDI (modified)', 'YUKON FFV', 'Colorado', 'ENCORE (LUV Engine)', 'Highlander', 'CIVIC HATCHBACK', 'TOUAREG', 'TTS COUPE', 'XK COUPE', 'Atlas Cross Sport 4MOTIO ...

# %%
# Classes within the 'VehicleClass' attribute
print("The categories in the column {} are as follows = {}".format("'VehicleClass'",set(co2Data.VehicleClass)))
print("The count of categories in the column {} = {}".format("'VehicleClass'", len(set(co2Data.VehicleClass))))
# Out:
# The categories in the column 'VehicleClass' are as follows = {'VAN - PASSENGER', 'COMPACT', 'PICKUP TRUCK - SMALL', 'STATION WAGON - SMALL', 'FULL-SIZE', 'SPECIAL PURPOSE VEHICLE', 'TWO-SEATER', 'MINICOMPACT', 'STATION WAGON - MID-SIZE', 'PICKUP TRUCK - STANDARD', 'MID-SIZE', 'VAN - CARGO', 'SUV - SMALL', 'MINIVAN', 'SUBCOMPACT', 'SUV - STANDARD'}
# The count of categories in the column 'VehicleClass' = 16

# %% [markdown]
# ## Target Encoding

# %% [markdown]
# - <i> Target encoding captures the relationship with the target variable without increasing dimensionality excessively, unlike one-hot encoding. </i>
# - <i> In contrast, label encoding can mislead the model because it imposes an ordinal relationship. </i>

# %%
def targetEncodingScheme(feature):
    classesFromFeature = list(set(co2Data[feature]))
    classesFromFeature = { key : [] for key in classesFromFeature}
    for index in range(len(co2Data)):
        classesFromFeature[co2Data[feature].iloc[index]].append(co2Data['CO2Emissions'].iloc[index])
    classesFromFeature = {category: format((sum(emissions) / len(classesFromFeature[category])), ".2f") for category, emissions in classesFromFeature.items()}
    return classesFromFeature

# %%
classesFromMake = targetEncodingScheme('Make')
classesFromMake
# Out:
# {'NISSAN': '236.13',
#  'PORSCHE': '258.55',
#  'CHRYSLER': '244.05',
#  'FORD': '261.96',
#  'LAND ROVER': '287.85',
#  'FIAT': '192.29',
#  'KIA': '214.31',
#  'DODGE': '276.90',
#  'BUGATTI': '522.00',
#  'HYUNDAI': '207.80',
#  'ASTON MARTIN': '344.28',
#  'ACURA': '221.08',
#  'SUBARU': '218.18',
#  'JAGUAR': '271.88',
#  'RAM': '294.18',
#  'CHEVROLET': '264.81',
#  'ROLLS-ROYCE': '389.38',
#  'CADILLAC': '266.23',
#  'VOLKSWAGEN': '209.57',
#  'BMW': '252.43',
#  'BENTLEY': '367.91',
#  'AUDI': '252.80',
#  'SRT': '389.00',
#  'MASERATI': '320.04',
#  'GMC': '300.61',
#  'LAMBORGHINI': '402.27',
#  'HONDA': '191.45',
#  'INFINITI': '252.62',
#  'MINI': '196.64',
#  'SMART': '151.43',
#  'TOYOTA': '225.27',
#  'JEEP': '250.49',
#  'LEXUS': '242.11',
#  'SCION': '198.12',
#  'ALFA ROMEO': '231.32',
#  'VOLVO': '230.17',
#  'LINCOLN': '264.70',
#  'MERCEDES-BENZ': '279.20',
#  'MITSUBISHI': '201.12',
#  'GENESIS': '282.57',
#  'BUICK': '233.94',
#  'MAZDA': '192.74'}

# %%
classesFromModel = targetEncodingScheme('Model')
classesFromModel
# Out:
# {'SAVANA 2500 PASSENGER': '426.00',
#  'Edge': '226.50',
#  'SANTA FE SPORT AWD': '259.83',
#  'COOPER S ROADSTER': '186.75',
#  'Wrangler Unlimited 4X4': '276.00',
#  '535i xDRIVE SEDAN': '237.00',
#  'WRANGLER JK 4X4': '298.50',
#  'SAVANA 1500 CARGO CONV': '362.00',
#  'Sierra WT': '275.00',
#  'AMG GLC 63 S 4MATIC+': '309.00',
#  'SILVERADO 4WD FFV': '301.30',
#  '435i xDRIVE GRAN COUPE': '234.00',
#  'STINGER AWD': '265.00',
#  'Panamera 4S Executive': '261.00',
#  'ProMaster City': '232.00',
#  '370Z': '262.83',
#  'MAZDA6 TURBO': '208.00',
#  'XTS AWD': '270.75',
#  'Palisade': '250.00',
#  'CAYENNE S HYBRID': '251.00',
#  'M4 Cabriolet': '289.50',
#  'TRANSIT CONNECT WAGON FFV': '246.00',
#  'AMG SLC 43': '236.00',
#  'GL 63 AMG': '369.00',
#  'CRUZE': '175.82',
#  '911 Carrera 4 Cabriolet': '238.00',
#  'Cayenne Turbo': '329.00',
#  'S5': '256.44',
#  'A4 ALLROAD QUATTRO': '223.50',
#  'Range Rover Evoque': '225.00',
#  'Macan': '264.00',
#  'COOPER S COUPE': '186.75',
#  'RANGE ROVER V8 5.0 SC FFV': '344.50',
#  'JOHN COOPER WORKS 3 DOOR': '203.00',
#  'M5 Sedan': '322.00',
#  'Flex AWD GTDI': '322.00',
#  'XJ R-Sport AWD': '276.00',
#  'XJL PORTFOLIO 3.0 AWD': '280.00',
#  'MDX SH-AWD': '254.80',
#  'M550i xDrive': '269.00',
#  'ACTIVEHYBRID 7L': '213.00',
#  '911 TURBO S CABRIOLET': '273.00',
#  'Traverse AWD': '276.50',
#  'AVENGER': '227.50',
#  'FORTWO CABRIOLET': '151.50',
#  'M240i xDRIVE COUPE': '227.50',
#  'Edge AWD': '250.00',
#  'iQ': '145.00',
#  'AMG CLA 45': '217.50',
#  'HURACAN SPYDER AWD': '350.00',
#  'TT RS Coupe': '241.00',
#  'AMG GLE 63 S COUPE 4MATIC': '363.00',
#  'MDX 4WD': '255.00',
#  'T-150 Wagon FFV': '328.00',
#  'Frontier 4WD': '310.00',
#  'COOPER ROADSTER': '176.75',
#  'Sierra': '288.88',
#  'RANGE ROVER SUPERCHARGED': '348.33',
#  'Highlander AWD': '245.00',
#  'NIRO TOURING': '129.00',
#  'XC40 T5 AWD': '215.00',
#  'V60 T5 AWD': '227.50',
#  'XV CROSSTREK AWD': '201.33',
#  'VIPER SRT': '364.00',
#  '911 Turbo S': '266.00',
#  '540i xDrive': '231.00',
#  'RIO': '177.38',
#  'RANGE ROVER TD6 DIESEL': '254.00',
#  'XC40 T4 AWD': '210.00',
#  'Alpina B6 xDrive Gran Coupe': '282.00',
#  'AMG GT 53 4MATIC+ Coupe': '264.00',
#  'KONA': '186.00',
#  'LS 500h': '195.00',
#  'Outlander 4WD': '229.00',
#  'Corolla XSE': '164.00',
#  'Metris Cargo LWB': '248.00',
#  '911 CARRERA 4 GTS CABRIOLET': '263.17',
#  'M6 COUPE': '330.25',
#  'Charger': '256.50',
#  'MX-5': '207.50',
#  'SIERRA FFV': '284.00',
#  'DB11 V8': '271.00',
#  'Range Rover Velar D180': '229.00',
#  'FOCUS (Start/Stop)': '170.00',
#  'EcoSport AWD': '217.00',
#  'Rogue': '192.00',
#  'M240i Coupe': '242.25',
#  'X7 xDrive40i': '254.00',
#  'RANGE ROVER V6 3.0 SC FFV': '280.00',
#  'GL 550 4MATIC': '361.00',
#  'ALPINA B7 xDRIVE': '292.00',
#  'GLS 450 4MATIC': '307.67',
#  'Ghibli S': '290.50',
#  'X6 M': '347.50',
#  'CIVIC TYPE R': '224.00',
#  'COROLLA LE ECO (2-mode)': '162.00',
#  'ECOSPORT AWD': '217.00',
#  'YARIS HATCHBACK': '169.00',
#  'S80 AWD': '264.00',
#  'CX-5 4WD (Cylinder Deactivation)': '208.00',
#  'ACTIVEHYBRID 3': '195.50',
#  'PATRIOT 4X4': '236.00',
#  'Transit Connect Van': '233.00',
#  'F-TYPE R AWD Coupe': '305.00',
#  'EXPEDITION 4X4 FFV': '357.00',
#  'xD': '183.00',
#  '500 HATCHBACK TURBO': '190.00',
#  'MDX SH-AWD A-SPEC': '258.00',
#  'SLS AMG GT ROADSTER': '359.00',
#  'GOLF R': '220.75',
#  'Sportage': '216.00',
#  'Renegade 4X4': '223.00',
#  'ES 350 F SPORT': '219.00',
#  'Grand Cherokee 4X4': '298.00',
#  '911 Turbo': '266.00',
#  'TERRAIN FFV': '217.00',
#  'XF S AWD': '243.00',
#  'CONTINENTAL GTC': '356.00',
#  'Altima SR/Platinum': '183.50',
#  'M5': '328.80',
#  'SUBURBAN 4WD': '308.00',
#  'Malibu Hybrid': '121.00',
#  'JOURNEY AWD': '288.50',
#  'F-150 RAPTOR 4WD': '339.00',
#  'SANTA FE 4WD': '267.00',
#  'CT6': '223.00',
#  '330i xDrive Touring': '207.00',
#  'E 550 4MATIC': '266.33',
#  'CRUZE PREMIER': '164.50',
#  'A7 QUATTRO': '244.00',
#  '1500 Classic 4X4': '333.50',
#  'GIULIA': '205.00',
#  'Yukon XL': '314.00',
#  '1500 Classic 4X4 FFV': '297.00',
#  'E 350 4MATIC': '230.00',
#  'ALPINA B7 xDRIVE LWB': '293.00',
#  'XJ AWD': '285.00',
#  'Tahoe FFV': '306.00',
#  '300 AWD (MDS)': '308.00',
#  'F-150 (Payload Pkg)': '284.56',
#  'ATS-V': '289.40',
#  'E 400 4MATIC': '243.50',
#  'Terrain AWD': '214.50',
#  'F-TYPE V8 R COUPE': '294.00',
#  'S5 SPORTBACK': '232.00',
#  'Charger AWD (MDS)': '312.00',
#  'C 350 4MATIC COUPE': '244.00',
#  'CLS 63 AMG 4MATIC': '301.00',
#  'NV200 Cargo Van': '218.00',
#  'Palisade AWD': '265.00',
#  'ACCORD SPORT': '187.00',
#  '330i xDrive Gran Turismo': '207.00',
#  'Murano': '240.00',
#  '550i xDRIVE GRAN TURISMO': '289.67',
#  'FR-S': '210.60',
#  'LACROSSE eASSIST': '190.67',
#  'F-TYPE PROJECT 7 CONVERTIBLE': '302.00',
#  'CHALLENGER GT AWD FFV': '253.00',
#  'Forte 5': '179.50',
#  'Passport AWD': '265.00',
#  'Cherokee': '224.33',
#  'E 250 BLUETEC 4MATIC': '197.00',
#  'LS 460 L AWD': '300.00',
#  'AMG GT COUPE': '302.50',
#  'X5 M': '340.00',
#  'A5 SPORTBACK QUATTRO': '203.00',
#  '428i CABRIOLET': '208.00',
#  'NX 300 AWD F SPORT': '232.00',
#  'Santa Fe': '225.00',
#  'GRAND CHEROKEE 4X4 FFV': '264.00',
#  'AMG GLE 63 S 4MATIC COUPE': '360.00',
#  'Micra': '187.00',
#  'E-PACE P300': '236.00',
#  'TRANSIT CONNECT TAXI': '232.00',
#  'NSX': '261.00',
#  'CT4-V AWD': '238.00',
#  'A 250 4MATIC': '201.00',
#  'SLK 300': '199.00',
#  'E350 WAGON FFV': '401.50',
#  'AMG GLE 43 4MATIC COUPE': '283.00',
#  '911 TURBO S EXCLUSIVE': '285.00',
#  'Beetle Convertible': '191.00',
#  'Discovery Sport': '246.00',
#  'C 300 4MATIC Wagon': '221.00',
#  'XT6 AWD': '277.00',
#  'A5 Cabriolet quattro': '205.00',
#  '300': '252.00',
#  'FIESTA ST': '188.60',
#  'RS 5 CABRIOLET': '302.50',
#  'Beetle Dune Convertible': '189.00',
#  'CHEROKEE 4X4 ACTIVE DRIVE LOCK': '262.50',
#  '300 SRT (MDS)': '317.00',
#  'Camry XSE': '215.00',
#  'Tiguan': '221.00',
#  'S 450 4MATIC SWB': '254.00',
#  'A8 QUATTRO TDI (modified)': '224.00',
#  'Yukon': '314.00',
#  '370Z Roadster': '275.00',
#  'BOXSTER': '222.83',
#  'COOPER S CLUBMAN': '202.17',
#  'X4 xDrive30i': '219.00',
#  'Cadenza': '238.00',
#  'DART': '197.00',
#  'Q5 TDI (modified)': '244.00',
#  'Z4 sDRIVE35i': '271.00',
#  'F-TYPE Convertible R-Dynamic AWD': '265.00',
#  'AMG GT S': '303.00',
#  'ATLAS 4MOTION': '282.00',
#  'V60 POLESTAR AWD': '253.00',
#  'ENCLAVE AWD': '303.00',
#  'GRAND CHEROKEE 4X4 SRT': '368.00',
#  'S 560 CABRIOLET': '276.00',
#  'IS 350': '244.67',
#  'Golf': '173.75',
#  'Corolla': '170.14',
#  'Q5 QUATTRO TDI (modified)': '244.00',
#  'YUKON FFV': '293.20',
#  'Colorado': '262.17',
#  'ENCORE (LUV Engine)': '194.00',
#  'Highlander': '241.50',
#  'CIVIC HATCHBACK': '166.33',
#  'TOUAREG': '291.67',
#  'TTS COUPE': '222.00',
#  'XK COUPE': '290.00',
#  'Atlas Cross Sport 4MOTION': '273.00',
#  'S5 Cabriolet': '243.00',
#  'PANAMERA 4 ST': '242.00',
#  'Q70 HYBRID': '177.00',
#  'SAVANA 2500 PASSENGER FFV': '423.00',
#  'SILVERADO 4WD': '307.60',
#  'TUCSON 4WD': '243.00',
#  'SLC 300': '202.33',
#  'Grand Cherokee 4X4 Trackhawk': '413.00',
#  'Challenger GT AWD': '258.00',
#  'CR-V AWD': '197.20',
#  '335i xDRIVE': '232.50',
#  'Z4 M40i': '216.00',
#  'GS 450h': '175.00',
#  'Tahoe 4WD': '324.50',
#  'Levante Trofeo': '360.00',
#  'AMG GT 63 4MATIC+ Coupe': '323.00',
#  'Encore GX AWD': '199.00',
#  'RANGE ROVER EVOQUE COUPE': '224.00',
#  'HIGHLANDER AWD LE': '242.00',
#  'BENTAYGA': '370.00',
#  'COOPER S 5 DOOR': '199.50',
#  'Cayenne S': '276.50',
#  'GRAND CARAVAN FFV': '269.33',
#  'V60 T6 AWD': '229.60',
#  'R8 SPYDER': '361.44',
#  'A8 TDI (modified)': '224.00',
#  '911 TARGA 4': '248.50',
#  'TTS COUPE QUATTRO': '231.33',
#  'GIULIA AWD': '217.00',
#  'IS 350 C': '244.00',
#  'SEDONA SX': '265.50',
#  'Sentra (Turbo)': '194.00',
#  'CTS Vsport': '298.60',
#  'X6 xDrive35i': '272.00',
#  'EXPLORER FFV AWD': '285.70',
#  'F-TYPE COUPE R-DYNAMIC AWD': '265.00',
#  'CHARGER SRT HELLCAT': '338.50',
#  'GLE 450 AMG SPORT 4MATIC COUPE': '281.00',
#  'DURANGO AWD SRT': '363.00',
#  'Giulia': '205.00',
#  'AMG CLA 45 4MATIC': '217.00',
#  '911 Speedster': '350.00',
#  'FOCUS SFE FFV': '164.00',
#  'A4 QUATTRO': '213.78',
#  '500 ABARTH': '192.00',
#  'REGAL AWD': '245.17',
#  'CADENZA': '244.67',
#  'AMG GLA 45 4MATIC': '229.00',
#  'Z4 sDrive30i': '200.00',
#  'M240i xDrive Coupe M Performance': '231.00',
#  '4RUNNER 4WD (Part-Time 4WD)': '302.50',
#  'GRAND CHEROKEE SRT 4X4 (MDS)': '366.50',
#  'SANTA FE AWD': '266.50',
#  'A8L QUATTRO': '299.50',
#  'Equinox': '197.00',
#  'ODYSSEY': '249.25',
#  'OPTIMA HYBRID': '141.75',
#  'CTS-V COUPE': '361.00',
#  'Highlander AWD LE': '242.00',
#  'M340i xDrive Sedan': '233.00',
#  'GOLF WAGON TDI (modified)': '197.00',
#  'SILVERADO FFV': '284.00',
#  'MAYBACH S 650': '355.00',
#  'GLK 350 4MATIC': '259.00',
#  'Silverado 4WD': '307.30',
#  'JOHN COOPER WORKS PACEMAN ALL4': '203.83',
#  '528i': '202.00',
#  'Golf SportWagen': '175.00',
#  'CHEROKEE 4X4 ACTIVE DRIVE I': '238.00',
#  'EQUINOX AWD': '250.30',
#  'NIRO': '114.00',
#  'ENCORE (SIDI with Stop/Start)': '185.00',
#  '1500 DIESEL': '275.00',
#  'MULSANNE EWB': '430.00',
#  'FORTE KOUP': '207.57',
#  'CT4 AWD': '225.50',
#  'Range Rover Velar P300': '248.00',
#  'ALTIMA 3.5': '212.00',
#  'SIERRA eASSIST 4WD': '303.50',
#  'Boxster S': '240.00',
#  'Q60 COUPE': '261.00',
#  'X2 xDrive28i': '214.50',
#  'PRIUS c': '112.25',
#  'COOPER CONVERTIBLE': '177.50',
#  'Yaris (SIL)': '164.50',
#  'Impala': '245.00',
#  'Canyon': '262.17',
#  'Pathfinder 4WD': '250.50',
#  'XFR-S': '305.00',
#  'Silverado FFV': '325.00',
#  '200 AWD FFV': '240.50',
#  'COOPER S COUNTRYMAN  ALL4': '220.00',
#  'Civic Hatchback': '166.33',
#  '650i xDrive Gran Coupe': '282.00',
#  'X1 xDrive28i': '215.00',
#  'MURANO': '227.50',
#  'Cayman S': '240.00',
#  'AMG GT R COUPE': '324.00',
#  'Corvette Z06': '324.50',
#  'QX60': '241.00',
#  'Ghibli S Q4': '295.00',
#  'GENESIS': '255.00',
#  '640i xDRIVE GRAN TURISMO': '241.00',
#  'CHALLENGER GT': '258.00',
#  'Quattroporte S': '292.50',
#  'TRANSIT CONNECT VAN': '227.50',
#  'CT 200h': '130.67',
#  'F-TYPE Coupe': '251.00',
#  'TAHOE 4WD FFV': '303.00',
#  'VERANO': '224.78',
#  'JOURNEY FFV': '274.86',
#  'Range Rover Sport 3.0': '277.50',
#  'GENESIS AWD': '305.50',
#  'CAMARO 2LS': '242.00',
#  'G70 AWD': '259.25',
#  'CHARGER SRT (MDS)': '307.00',
#  'Colorado 4WD': '277.00',
#  'Challenger (MDS)': '299.33',
#  '230i COUPE': '208.00',
#  'LACROSSE FFV': '264.00',
#  'S 400 4MATIC': '248.00',
#  'RANGE ROVER EVOQUE CONVERTIBLE': '237.00',
#  'Shelby GT350 Mustang': '341.50',
#  'C 63 AMG': '347.00',
#  'F-PACE 35t': '277.00',
#  'Q50': '232.00',
#  'Renegade 4X4 Trailhawk': '230.00',
#  'Odyssey': '250.00',
#  'A6 allroad': '247.00',
#  'XF 25t AWD': '207.00',
#  'B 250 4MATIC': '210.25',
#  'Renegade': '213.00',
#  'F-PACE 25t': '227.00',
#  'YUKON XL': '297.83',
#  'TIGUAN': '251.00',
#  'LR4': '333.00',
#  'SOUL TURBO': '199.00',
#  'Explorer FFV AWD': '293.50',
#  'CRUZE LIMITED': '190.75',
#  'TLX A-SPEC': '209.00',
#  'F-TYPE Coupe R-Dynamic': '277.50',
#  'Cooper Clubman ALL4': '207.67',
#  'G80 AWD': '297.60',
#  'RANGE ROVER VELAR': '251.00',
#  '335i SEDAN': '223.00',
#  'TUNDRA 4WD': '366.33',
#  'A5 CABRIOLET QUATTRO': '223.80',
#  'AMG GT R Coupe': '327.00',
#  'MAZDA3 5-DOOR': '173.11',
#  'TRANSIT CONNECT VAN FFV': '237.60',
#  'JETTA GLI': '206.50',
#  'Mazda3 4-Door': '179.50',
#  '430i xDrive Cabriolet': '213.00',
#  'FUSION': '206.13',
#  'Compass': '214.50',
#  '1500 eTorque': '271.50',
#  '340i xDRIVE GRAN TURISMO': '236.50',
#  'FJ CRUISER 4WD': '308.50',
#  '340i': '222.83',
#  '650i xDRIVE GRAN COUPE': '290.25',
#  'A8L TDI (modified)': '224.00',
#  'ALPINA B6 xDRIVE GRAN COUPE': '289.67',
#  'Challenger': '291.33',
#  'MAZDA5': '225.67',
#  'V60 CC': '202.00',
#  'Huracan Spyder AWD': '370.00',
#  'F-150 4X4': '293.89',
#  'S 65 AMG COUPE': '345.00',
#  'C 250 COUPE': '216.00',
#  '911 Carrera S Cabriolet': '247.67',
#  '200 FFV': '211.83',
#  'FRONTIER': '285.50',
#  '230i xDRIVE CABRIOLET': '210.50',
#  'VIPER': '387.00',
#  'C 63 AMG COUPE': '353.00',
#  'GranTurismo Convertible': '354.00',
#  'GT': '401.00',
#  'M8 Cabriolet Competition': '322.00',
#  'Flying Spur': '373.00',
#  'CAMRY HYBRID XLE/SE': '134.60',
#  'MALIBU LIMITED': '202.00',
#  'RLX': '232.50',
#  'TRAX AWD': '205.00',
#  'Encore AWD (SIDI with Stop/Start)': '205.00',
#  'LS 600h L': '264.67',
#  'FIESTA': '177.88',
#  'Cooper S 3 Door': '197.00',
#  'ALLROAD QUATTRO': '242.00',
#  'Panamera GTS': '295.00',
#  'Panamera Turbo': '261.00',
#  'CAMRY XLE/XSE': '173.00',
#  'R8': '357.67',
#  'NIRO FE': '110.00',
#  'Silverado': '287.12',
#  'RC F': '288.00',
#  'SORENTO 4WD': '262.00',
#  '435i COUPE': '230.80',
#  'Q60 AWD COUPE': '265.00',
#  'AMG GT S COUPE': '302.50',
#  'MACAN GTS': '287.00',
#  'CHEROKEE': '229.00',
#  'MAZDA6 (SIL)': '192.00',
#  'PRIUS v': '130.25',
#  'YUKON DENALI 4WD': '323.00',
#  '911 CARRERA 4 GTS': '257.50',
#  'RAV4 HYBRID AWD': '170.00',
#  'E 350 CABRIOLET': '239.00',
#  'COOPER S COUNTRYMAN ALL4': '208.12',
#  'Silverado 4WD LT Trail Boss': '319.50',
#  '500 CABRIO TURBO': '179.00',
#  'EXPEDITION MAX 4X4': '321.00',
#  'IMPALA': '227.62',
#  'M240i xDRIVE CABRIOLET': '227.50',
#  'GRANTURISMO': '353.00',
#  'SIERRA 4WD FFV': '301.50',
#  'DURANGO AWD (MDS)': '332.67',
#  'Fusion': '203.50',
#  'ENCORE': '196.33',
#  'Beetle': '191.00',
#  'RDX AWD': '243.75',
#  'S 600': '344.33',
#  'E 350 COUPE': '235.00',
#  'EDGE AWD': '267.46',
#  '535d xDRIVE': '212.50',
#  'IS 250 AWD': '239.00',
#  'ECOSPORT': '195.00',
#  'QUATTROPORTE S': '300.00',
#  'COROLLA LE ECO (1-mode)': '159.67',
#  'C-MAX HYBRID': '138.67',
#  'Niro': '114.00',
#  'Cruze Premier': '172.00',
#  'Range Rover Evoque P300': '242.00',
#  'COROLLA': '172.00',
#  'CTS-V': '332.67',
#  'Ghost EWB': '398.50',
#  '1500': '314.75',
#  'EXPLORER AWD': '284.50',
#  'NEW WRANGLER UNLIMITED 4X4': '268.33',
#  'VANTAGE GT': '349.75',
#  'E 450 4MATIC': '244.00',
#  'Continental GT Convertible': '332.00',
#  'AVENTADOR COUPE LP 740': '461.00',
#  'Levante S': '327.00',
#  '1500 4X4 (MDS)': '341.33',
#  'XC90 AWD': '294.00',
#  'Yukon XL 4WD FFV': '327.25',
#  'Sierra FFV': '325.00',
#  'Sedona': '271.50',
#  'LACROSSE': '246.83',
#  'PROMASTER CITY': '229.33',
#  'Range Rover Sport TD6 Diesel': '256.00',
#  'ACCORD SPORT/TOURING': '211.00',
#  'Phantom': '382.00',
#  'F-150 4X4 Limited': '296.00',
#  'Accord Hybrid': '117.00',
#  'John Cooper Works Clubman ALL4': '217.00',
#  'PATHFINDER': '242.00',
#  'A6 quattro': '218.33',
#  'CIVIC HATCHBACK SPORT': '168.50',
#  'RANGE ROVER': '287.00',
#  'E-PACE P250': '231.00',
#  'Escape AWD': '220.00',
#  '911 TARGA 4S': '254.33',
#  'Enclave AWD': '277.50',
#  'M2': '254.00',
#  'Sienna AWD': '274.00',
#  '1500 Classic': '315.00',
#  'Nautilus AWD': '254.00',
#  'AMG GT ROADSTER': '304.00',
#  '228i xDRIVE CABRIOLET': '209.00',
#  'GX 460': '330.00',
#  'CX-5 Turbo 4WD': '230.00',
#  'WRX': '255.50',
#  'DURANGO AWD': '297.25',
#  'ORLANDO': '239.50',
#  'Murano AWD': '242.00',
#  'Shelby GT500 Mustang': '392.00',
#  'PANAMERA 4S EXECUTIVE': '256.67',
#  'TITAN 4WD': '369.67',
#  'Huracan Performante Spyder': '370.00',
#  'Maybach S 650': '355.00',
#  'SUBURBAN': '297.83',
#  'MIRAGE': '141.83',
#  '911 GT3RS': '334.00',
#  'CHARGER AWD (MDS)': '311.00',
#  'X4 xDRIVE35i': '254.00',
#  'XT4 AWD': '227.00',
#  'TRIBECA AWD': '301.00',
#  'E 63 AMG 4MATIC': '297.00',
#  'AMG S 65 Coupe': '343.00',
#  '500X AWD': '221.00',
#  'TT ROADSTER QUATTRO': '210.00',
#  'F-PACE SVR': '303.00',
#  'NEW COMPASS 4X4': '221.50',
#  'COOPER COUPE': '171.50',
#  'RX 450h L AWD': '190.00',
#  '500': '193.25',
#  'IMPREZA AWD': '207.88',
#  'Acadia': '245.00',
#  'PILOT': '259.00',
#  'YUKON XL FFV': '293.20',
#  'CX-5 Diesel 4WD': '227.00',
#  'FOCUS RS AWD': '254.33',
#  'XE 25t AWD': '200.00',
#  'XKR-S CONVERTIBLE': '314.00',
#  'Cooper 5 Door': '177.67',
#  'BEETLE DUNE': '197.67',
#  '1500 Classic EcoDiesel': '278.00',
#  'Camry Hybrid XLE/SE': '121.00',
#  'GR Supra': '208.00',
#  'Wrangler JL Unlimited 4X4': '268.33',
#  'X3 M40i': '240.33',
#  'QX70 AWD': '305.75',
#  'Metris Passenger': '268.00',
#  'YUKON DENALI XL AWD': '365.50',
#  'M240i xDrive Cabriolet': '231.00',
#  'Forte': '173.25',
#  '320i': '200.50',
#  '1500 4X4': '337.20',
#  'tC': '209.33',
#  'Durango AWD': '298.00',
#  'V60 CC AWD': '237.00',
#  'CAYMAN GTS': '240.33',
#  'MUSTANG CONVERTIBLE': '266.75',
#  'ROGUE AWD': '200.60',
#  'GLC 300 4MATIC COUPE': '235.00',
#  'Yukon 4WD': '324.50',
#  'EQUINOX FFV': '217.00',
#  'CAYENNE PLATINUM': '281.00',
#  'CX-5 4WD': '207.86',
#  'XC60 T5': '210.33',
#  '750i xDRIVE SWB': '283.00',
#  'Sonata': '193.25',
#  'Mirage': '147.00',
#  'QASHQAI AWD': '196.50',
#  'Qashqai': '199.00',
#  'F-150 FFV (LT Tire Pkg)': '283.33',
#  'CX-3 (SIL)': '186.00',
#  'MAZDA3 4-DOOR (i-ELOOP)': '169.75',
#  'F-TYPE COUPE': '247.20',
#  'Telluride AWD': '264.00',
#  'CHALLENGER SRT HELLCAT': '345.80',
#  'CAMRY XSE': '215.00',
#  '440i xDrive Cabriolet': '242.00',
#  'Q3 quattro': '248.00',
#  'C 300 4MATIC WAGON': '222.00',
#  'X3 M': '339.00',
#  'COOPER COUNTRYMAN': '189.00',
#  'RIDGELINE AWD': '286.00',
#  '124 Spider': '186.00',
#  '430i xDRIVE GRAN COUPE': '210.50',
#  'RENEGADE 4X4': '216.67',
#  'RC 350': '245.00',
#  'Pacifica (Stop-Start)': '249.00',
#  '328d xDRIVE TOURING': '184.25',
#  'MICRA': '183.38',
#  'Santa Fe XL': '268.00',
#  'V60 T5': '197.80',
#  '300 FFV': '234.00',
#  'CR-Z': '157.50',
#  '911 TARGA 4 GTS': '258.50',
#  'Trax 4WD': '214.00',
#  'Charger Widebody (MDS)': '305.00',
#  'COMPASS': '222.06',
#  'KICKS': '169.00',
#  'Escape': '199.50',
#  'Rapide AMR': '332.00',
#  'AMG C 63 COUPE': '285.00',
#  'CRUZE LIMITED ECO': '174.00',
#  'RC 350 AWD': '257.67',
#  'Panamera GTS ST': '313.00',
#  'AMG E 53 4MATIC+ Cabriolet': '245.00',
#  'SOUL': '206.18',
#  '500 CABRIO': '176.00',
#  'CAMRY HYBRID LE': '128.75',
#  'E 400 4MATIC WAGON': '255.25',
#  'LANCER': '198.18',
#  'IS 250 C': '222.00',
#  'T-150 Wagon': '350.50',
#  'C 350 COUPE': '242.00',
#  'Range Rover Velar P250': '238.00',
#  'Q7 TDI (modified)': '290.00',
#  'SEDONA SXL': '293.33',
#  'Stelvio AWD Quadrifoglio': '290.00',
#  'CTS': '230.78',
#  'F-TYPE R CONVERTIBLE AWD': '311.00',
#  'SLK 350': '227.00',
#  'Forester AWD': '192.00',
#  'AMG E 43 4MATIC': '258.00',
#  'HIGHLANDER': '249.83',
#  'TTS ROADSTER QUATTRO': '236.00',
#  'F-150 FFV': '279.48',
#  'CANYON': '254.50',
#  'Boxster': '224.00',
#  'CIVIC COUPE': '163.38',
#  'PANAMERA GTS': '295.00',
#  'E 300 4MATIC': '235.17',
#  'Aventador Roadster': '493.00',
#  'SUBURBAN FFV': '293.20',
#  'GRAND CHEROKEE SRT8': '368.00',
#  'SLK 250': '206.00',
#  'IMPREZA 5-DOOR AWD': '193.50',
#  'GLE 400 4MATIC': '280.00',
#  'MKS AWD': '273.83',
#  'AMG G 65': '472.00',
#  'E 63 AMG S 4MATIC WAGON': '308.00',
#  'A5 QUATTRO': '215.50',
#  'Jetta': '162.50',
#  'X7 M50i': '318.00',
#  'MDX Hybrid AWD': '210.00',
#  'XC70 3.2 AWD': '260.00',
#  'S90 T5 AWD': '210.50',
#  'ROGUE': '192.33',
#  'Tundra 4WD': '372.33',
#  'FRONTIER 4WD': '314.29',
#  'IMPREZA 4-DOOR AWD': '191.00',
#  'Cullinan': '384.00',
#  'SIERRA': '295.47',
#  'QASHQAI': '203.50',
#  'Yaris': '155.00',
#  'EXPLORER': '245.25',
#  'IMPALA DUAL FUEL': '242.50',
#  'GOLF ALLTRACK': '221.67',
#  'Sorento': '225.00',
#  'CX-5 (SIL)': '188.00',
#  'ESCALADE AWD': '330.00',
#  'XFR': '300.00',
#  'Panamera 4S': '261.00',
#  'Transit Connect Van FFV': '214.00',
#  'Mazda6': '187.50',
#  'Silverado 4WD Trail Boss': '339.00',
#  'RANGE ROVER SUPERCHARGED LWB': '348.33',
#  'F-TYPE CONVERTIBLE': '247.20',
#  'VIPER SRT COUPE': '363.00',
#  'IONIQ BLUE': '96.00',
#  'X5 M50i': '302.00',
#  'Tacoma 4WD D-Cab Off-Road': '300.00',
#  'RS 5 Sportback': '268.00',
#  'SONIC': '185.94',
#  'Fit': '163.67',
#  'Corolla Hybrid': '106.00',
#  'Altima': '174.00',
#  'AMG GLE 63 S 4MATIC': '365.75',
#  'CX-5 (Cylinder Deactivation)': '201.00',
#  'AMG GT C Roadster': '315.00',
#  'GS 200t F SPORT': '227.00',
#  'S 63 AMG COUPE': '304.00',
#  'JUKE NISMO RS': '194.00',
#  'COLORADO ZR2 4WD': '323.00',
#  'Q3 QUATTRO': '239.33',
#  'V12 VANTAGE S': '401.75',
#  'COOPER CLUBMAN ALL4': '213.25',
#  'CHALLENGER SRT DEMON': '339.00',
#  'AMG GLC 43 4MATIC Coupe': '265.00',
#  'DART GT': '209.00',
#  'EXPEDITION EL 4X4': '337.50',
#  'XJL PORTFOLIO AWD': '280.00',
#  'Traverse': '261.00',
#  'GALLARDO COUPE': '380.50',
#  'M4 COUPE': '276.25',
#  'TOWN & COUNTRY FFV': '276.50',
#  'Huracan Coupe AWD': '370.00',
#  'M3': '277.50',
#  'TAURUS FFV AWD': '264.50',
#  '230i xDRIVE COUPE': '206.00',
#  'Arteon 4MOTION': '239.00',
#  'HURACAN': '333.67',
#  'BRZ tS': '239.00',
#  'CORVETTE': '275.75',
#  '335i': '225.50',
#  'TERRAIN AWD': '251.50',
#  'A7 QUATTRO TDI (modified)': '215.00',
#  'Suburban FFV': '306.00',
#  '4RUNNER (Part-Time 4WD)': '297.00',
#  'Eclipse Cross 4WD': '216.00',
#  'VELOSTER TURBO': '196.50',
#  'Yukon XL FFV': '306.00',
#  '528i xDRIVE SEDAN': '209.00',
#  '440i xDrive Gran Coupe': '230.50',
#  'Boxster GTS': '253.00',
#  'A4 ULTRA': '177.00',
#  'Insight Touring': '114.00',
#  'Golf R': '222.50',
#  'Discovery': '311.00',
#  'X4 M Competition': '339.00',
#  'F-150 Raptor 4X4': '336.00',
#  'CAYENNE TURBO S': '342.67',
#  'VELOSTER': '182.29',
#  'PANAMERA 4 EXECUTIVE': '235.00',
#  'DB9': '359.00',
#  '911 Carrera T': '267.00',
#  'MAXIMA': '231.50',
#  '740Ld xDRIVE SEDAN': '238.00',
#  'SAVANA 1500 PASSENGER AWD': '371.00',
#  'Equinox AWD': '209.50',
#  '430i Coupe': '204.00',
#  'G 63 AMG': '416.50',
#  'Camaro ZL1': '352.00',
#  'VERSA': '167.00',
#  'GLA 250 4MATIC': '190.40',
#  'TRAX 4WD': '207.50',
#  'F-TYPE Convertible R-Dynamic': '277.50',
#  'MACAN TURBO KIT': '286.00',
#  'RANGE ROVER SPORT V8 5.0 SC': '345.00',
#  'SONATA HYBRID LIMITED': '140.50',
#  'ATLAS': '233.00',
#  '228i CABRIOLET': '205.00',
#  'RANGE ROVER SPORT V6 3.0 SC FFV': '281.50',
#  'SL 63 AMG': '288.50',
#  'ESCAPE FFV': '224.00',
#  'Ghost': '398.50',
#  'AMG G 63': '411.25',
#  'CHARGER SRT 392 HEMI': '297.00',
#  'Qashqai AWD': '198.00',
#  'ENCLAVE': '291.80',
#  'Avalon': '220.00',
#  'XTS': '260.80',
#  'X3 xDRIVE28d': '211.67',
#  'OPTIMA TURBO': '224.00',
#  'RS 7 QUATTRO': '313.00',
#  '911 Targa 4S': '239.50',
#  'Acadia AWD': '256.00',
#  'Ghibli': '286.00',
#  'CHEROKEE 4X4 ACTIVE DRIVE II': '246.00',
#  'Sienna': '256.50',
#  'EDGE (Start/Stop)': '228.50',
#  'Encore AWD': '214.00',
#  'VENZA': '245.50',
#  'Explorer AWD': '274.25',
#  'F-TYPE V8 S CONVERTIBLE': '294.00',
#  'Charger (MDS)': '300.00',
#  'Sentra SR': '171.00',
#  'Stelvio AWD': '226.00',
#  '328d xDRIVE': '184.25',
#  'T-150 WAGON FFV': '342.17',
#  'CL 550 4MATIC': '304.00',
#  '650i xDRIVE CABRIOLET': '290.25',
#  'C 300 4MATIC Coupe': '221.00',
#  'AVENTADOR S ROADSTER': '464.00',
#  '430i xDrive Coupe': '213.00',
#  'QX60 HYBRID AWD': '203.50',
#  'GIULIA QUADRIFOGLIO': '280.00',
#  'XT5': '240.67',
#  'JETTA TDI (modified)': '186.25',
#  'QX30': '200.00',
#  'ML 63 AMG 4MATIC': '357.50',
#  'ARMADA 4WD': '374.67',
#  'CRUZE HATCHBACK': '173.00',
#  'AMG GLC 43 4MATIC COUPE': '312.50',
#  'AMG CLS 63 S 4MATIC': '308.00',
#  'MAZDA3 4-DOOR': '169.75',
#  'CHARGER (MDS)': '295.56',
#  'S5 QUATTRO': '265.00',
#  'CTS SEDAN': '240.00',
#  'WRX AWD': '255.00',
#  '911 Targa 4 GTS': '258.50',
#  'F-150 RAPTOR 4X4': '376.50',
#  'Encore GX': '198.00',
#  'Colorado ZR2 4WD': '328.50',
#  'NX 200t AWD F SPORT': '230.33',
#  'OPTIMA HYBRID EX': '148.50',
#  'M4 Coupe Competition': '285.67',
#  'PANAMERA 4': '250.67',
#  'A6 QUATTRO': '230.56',
#  '328i': '196.50',
#  'NAVIGATOR 4X4': '326.00',
#  'Huracan Coupe': '368.00',
#  'XC90 T6 AWD': '246.80',
#  'Highlander Hybrid AWD Limited/Platinum': '156.00',
#  'Cooper S Convertible': '199.33',
#  'GS 350 AWD': '254.67',
#  'S 550 4MATIC LWB': '283.25',
#  'Discovery TD6 Diesel': '279.00',
#  'Santa Fe XL Ultimate AWD': '297.00',
#  'FORESTER AWD': '214.67',
#  'B 250': '188.60',
#  'AMG S 65': '355.33',
#  '1500 EcoDiesel': '243.00',
#  'Z4 sDRIVE35is': '280.00',
#  'M760Li xDrive': '355.00',
#  'E 400 4MATIC COUPE': '243.50',
#  'CONTINENTAL AWD': '285.20',
#  'RANGE ROVER SPORT V8 5.0 SC FFV': '334.50',
#  'SIENNA': '260.00',
#  'F-TYPE CONVERTIBLE R-DYNAMIC': '277.50',
#  'Phantom EWB': '382.00',
#  'GLE 550 4MATIC': '323.33',
#  'S 65 AMG': '357.00',
#  '500 ABARTH CABRIO': '191.33',
#  'Silverado 4WD Custom Trail Boss': '353.33',
#  'Escape Hybrid': '136.00',
#  'Wrangler Unlimited 4X4 eTorque': '266.50',
#  'T-150 WAGON': '344.60',
#  'EQUUS': '307.33',
#  'AVENTADOR S COUPE': '454.00',
#  'Beetle Dune': '189.00',
#  'IS 300': '217.00',
#  'Cruze Hatchback Diesel': '178.00',
#  'TT Roadster quattro': '213.00',
#  'Journey': '261.00',
#  'CTS SPORT WAGON': '256.50',
#  'AMG C 63': '269.50',
#  'S8': '309.00',
#  'Cooper Countryman ALL4': '209.67',
#  'FORTWO COUPE': '151.33',
#  'ENCORE AWD (LE2 Engine)': '196.00',
#  'Veloster': '195.50',
#  'ACTIVEHYBRID 5': '216.33',
#  'VENENO ROADSTER': '423.00',
#  'AMG C 43 4MATIC CABRIOLET': '256.00',
#  'EQUINOX AWD FFV': '233.17',
#  'Highlander Hybrid AWD': '175.50',
#  'Quattroporte S Q4': '301.00',
#  'F-TYPE S CONVERTIBLE': '263.25',
#  'DISCOVERY SPORT': '248.67',
#  'Atlas 4MOTION': '286.00',
#  'Versa': '170.75',
#  '4RUNNER 4WD': '301.40',
#  '330i xDrive Sedan': '195.00',
#  'Golf GTI': '202.67',
#  'SPORTAGE': '236.67',
#  'YUKON DENALI AWD': '330.00',
#  'Kona AWD': '201.50',
#  'iM': '176.50',
#  'S60': '223.00',
#  '228i xDRIVE': '207.00',
#  '740Li xDRIVE': '242.00',
#  'Accord': '182.80',
#  'X3 xDRIVE30i': '223.00',
#  'SIERRA eASSIST': '278.00',
#  'SLK 55 AMG': '245.00',
#  'TRANSIT CONNECT': '223.00',
#  'CX-9 4WD': '267.00',
#  'AMG C 43 4MATIC': '248.50',
#  'XJ R-SPORT AWD': '276.00',
#  'IMPALA FFV': '245.83',
#  '911 TURBO': '272.67',
#  'COLORADO': '254.50',
#  'RAV4': '200.20',
#  'WRANGLER UNLIMITED 4X4 (4-DOOR)': '308.00',
#  'XC60 T6': '226.00',
#  'ENCORE AWD (LUV Engine)': '208.00',
#  'S7 QUATTRO': '265.00',
#  'Mazda3 4-Door 4WD': '192.00',
#  'CLA 250': '188.17',
#  'PACIFICA (Stop-Start)': '249.00',
#  'LS 500': '240.00',
#  'X3 xDrive30i': '219.00',
#  'CIVIC': '168.40',
#  'CLS 400 4MATIC': '247.00',
#  'Range Rover Sport Supercharged': '294.00',
#  'COOPER S CLUBMAN ALL4': '217.33',
#  'TACOMA 4WD D-CAB OFF-ROAD': '300.00',
#  'STELVIO QUADRIFOGLIO': '292.00',
#  'M8 Gran Coupe': '322.00',
#  'ML 350 4MATIC FFV': '267.00',
#  'CIVIC Si': '216.00',
#  'AVENTADOR ROADSTER': '451.75',
#  'Camry AWD XLE/XSE': '197.00',
#  'ECLIPSE CROSS 4WD': '216.00',
#  'SONATA HYBRID': '139.80',
#  'RS 5 Coupe': '262.00',
#  'C 300 4MATIC CABRIOLET': '223.00',
#  'Metris Cargo': '251.00',
#  'Cooper S Clubman ALL4': '216.00',
#  'M240i COUPE': '236.25',
#  'F-TYPE SVR AWD Convertible': '299.00',
#  'M6': '331.17',
#  'TITAN 4WD PRO-4X': '332.00',
#  'RAV4 AWD': '210.00',
#  'XV CROSSTREK HYBRID AWD': '175.00',
#  'M235i xDRIVE CABRIOLET': '238.00',
#  'SANTA FE SPORT ULTIMATE AWD': '264.00',
#  'Charger SRT Hellcat': '339.00',
#  '370Z COUPE': '259.50',
#  'CHEROKEE FFV': '217.17',
#  'OUTLANDER': '196.00',
#  'Mirage G4': '150.50',
#  'S7': '273.60',
#  '428i COUPE': '201.60',
#  'Civic Coupe': '174.00',
#  'CLA 250 4MATIC': '203.33',
#  'F-150': '275.56',
#  'Sierra WT 4WD': '280.00',
#  'CC 4MOTION': '277.00',
#  'SPARK': '161.67',
#  'RX 350 AWD': '256.75',
#  '911 CARRERA S': '243.12',
#  'Wraith': '387.50',
#  'CTS SEDAN Vsport': '294.00',
#  'Kicks': '169.00',
#  'AMG C 43 4MATIC Wagon': '255.00',
#  '228i xDRIVE COUPE': '200.00',
#  'AMG GT C COUPE': '322.00',
#  'LS 460': '284.00',
#  'Corolla Hatchback': '163.00',
#  'R8 QUATTRO': '338.00',
#  'CT4': '217.50',
#  'YUKON XL 4WD': '315.25',
#  'PANAMERA TURBO S': '297.00',
#  'S80 T5': '193.00',
#  '911 Turbo S Cabriolet': '267.00',
#  '911 Carrera': '229.00',
#  'CLS 450 4MATIC': '213.00',
#  'AMG SLK 55': '252.00',
#  'Sonata SE': '190.00',
#  'UX 200': '168.00',
#  'SAVANA 1500 PASSENGER': '362.00',
#  'FIT': '162.15',
#  'R8 Spyder': '347.00',
#  'JETTA TURBO HYBRID': '124.00',
#  'F-TYPE R COUPE AWD': '311.00',
#  'TLX SH-AWD A-SPEC/Limited Edition': '240.00',
#  'M235i CABRIOLET': '240.25',
#  'SAVANA 1500 CARGO': '349.00',
#  'SILVERADO eASSIST 4WD': '303.50',
#  'JOHN COOPER WORKS CLUBMAN ALL4': '219.00',
#  'Huracan Performante Coupe': '370.00',
#  'S 560 Cabriolet': '275.00',
#  'CAMRY': '203.20',
#  'E 450 4MATIC Wagon': '254.00',
#  'RAPIDE': '359.00',
#  'SORENTO': '243.57',
#  'Encore (SIDI with Stop/Start)': '194.00',
#  'Panamera': '250.00',
#  '1500 Classic 4X4 EcoDiesel': '289.00',
#  'CIVIC HYBRID': '120.00',
#  'BOXSTER S': '236.33',
#  '330i xDRIVE GRAN TURISMO': '210.50',
#  'JETTA HYBRID': '123.00',
#  'EXPRESS 1500 CARGO CONV': '362.00',
#  '650i xDRIVE COUPE': '282.20',
#  '340i xDRIVE': '233.17',
#  'Mustang Convertible': '261.83',
#  '440i Coupe': '238.00',
#  'GOLF SPORTWAGEN': '194.25',
#  '370Z ROADSTER': '269.14',
#  'COROLLA MATRIX': '192.50',
#  'GS F': '293.00',
#  'TT COUPE QUATTRO': '209.00',
#  'Titan 4WD Pro-4X': '322.00',
#  'CAYENNE DIESEL (modified)': '273.50',
#  'Grand Caravan FFV': '275.00',
#  'CROSSTREK AWD': '204.25',
#  '328i SEDAN': '200.00',
#  'Camry XLE/XSE': '176.00',
#  'GOLF WAGON': '217.00',
#  'NX 300h AWD': '172.67',
#  'MKT LIVERY': '245.00',
#  'Escape Hybrid AWD': '139.00',
#  '1500 4X4 EcoDiesel': '260.00',
#  'AMG C 43 4MATIC Coupe': '255.00',
#  'FLEX AWD GTDI': '321.50',
#  '435i GRAN COUPE': '221.00',
#  'Silverado WT 4WD': '280.00',
#  'PANAMERA TURBO': '285.00',
#  '640i xDrive Gran Turismo': '241.00',
#  'S60 INSCRIPTION T5 AWD': '226.00',
#  '200': '215.50',
#  '430i xDRIVE COUPE': '210.50',
#  'AMG C 63 S Coupe': '277.00',
#  'WRX STI AWD TYPE RA': '296.00',
#  'A3 Cabriolet quattro': '222.50',
#  'Continental GT': '327.50',
#  'xB': '226.00',
#  'V90 CC T5 AWD': '214.00',
#  'HIGHLANDER AWD (Start/Stop System)': '247.00',
#  'PATRIOT 4X4 TRAIL RATED': '257.00',
#  'Cullinan Black Badge': '386.00',
#  '911 Carrera 4 GTS Cabriolet': '255.00',
#  'T-150 Wagon FFV 4WD': '340.00',
#  'S60 CC T5 AWD': '229.50',
#  'COMPASS 4X4': '233.10',
#  'IS 200t': '213.00',
#  'Altima AWD SR/Platinum': '190.00',
#  ...}

# %%
classesFromVehicleClass = targetEncodingScheme('VehicleClass')
classesFromVehicleClass
# Out:
# {'VAN - PASSENGER': '397.21',
#  'COMPACT': '218.04',
#  'PICKUP TRUCK - SMALL': '276.33',
#  'STATION WAGON - SMALL': '202.54',
#  'FULL-SIZE': '264.52',
#  'SPECIAL PURPOSE VEHICLE': '237.66',
#  'TWO-SEATER': '282.42',
#  'MINICOMPACT': '236.63',
#  'STATION WAGON - MID-SIZE': '241.21',
#  'PICKUP TRUCK - STANDARD': '301.94',
#  'MID-SIZE': '222.82',
#  'VAN - CARGO': '361.50',
#  'SUV - SMALL': '236.37',
#  'MINIVAN': '261.70',
#  'SUBCOMPACT': '244.08',
#  'SUV - STANDARD': '306.55'}

# %%
co2Data['Make'] = co2Data['Make'].map(classesFromMake).astype(float)
co2Data['Model'] = co2Data['Model'].map(classesFromModel).astype(float)
co2Data['VehicleClass'] = co2Data['VehicleClass'].map(classesFromVehicleClass).astype(float)

# %%
co2Data[:18]
# Out:
#       Make   Model  VehicleClass  EngineSize  Cylinders  FuelConsumptionCity  \
# 0   221.08  200.29        218.04         2.0          4                  9.9
# 1   221.08  200.29        218.04         2.4          4                 11.2
# 2   221.08  138.00        218.04         1.5          4                  6.0
# 3   221.08  255.00        236.37         3.5          6                 12.7
# 4   221.08  243.75        236.37         3.5          6                 12.1
# 5   221.08  232.50        222.82         3.5          6                 11.9
# 6   221.08  232.00        222.82         3.5          6                 11.8
# 7   221.08  261.00        222.82         3.7          6                 12.8
# 8   221.08  261.00        222.82         3.7          6                 13.4
# 9   221.08  225.33        218.04         2.4          4                 10.6
# 10  221.08  225.33        218.04         2.4          4                 11.2
# 11  221.08  225.33        218.04         3.5          6                 12.1
# 12  231.32  195.00        282.42         1.8          4                  9.7
# 13  344.28  359.00        236.63         5.9         12                 18.0
# 14  344.28  359.00        244.08         5.9         12                 18.0
# 15  344.28  350.60        282.42         4.7          8                 17.4
# 16  344.28  350.60        282.42         4.7          8                 18.1
# 17  344.28  350.60        282.42         4.7          8                 17.4
#
#     CO2Emissions
# 0            196
# 1            221
# 2            136
# 3            255
# 4            244
# 5            230
# 6            232
# 7            255
# 8            267
# 9            212
# 10           225
# 11           239
# 12           193
# 13           359
# 14           359
# 15           338
# 16           354
# 17           338

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# ### Pearson's Correlation Coefficient
#
# - The Pearson correlation coefficient \( r \) is a measure of the linear relationship between two variables. It is calculated using the formula:
#
# $$
# r = \frac{n \sum (XY) - \sum X \sum Y}{\sqrt{[n \sum (X^2) - (\sum X)^2][n \sum (Y^2) - (\sum Y)^2]}}
# $$
#
# - Dependent Variable    = CO2Emissions
# - Independent Variables = EngineSize, Cylinders, FuelConsumptionCity

# %%
def Karl_Pearson_Correlation(indeFeature, depenFeature):
    X = co2Data[indeFeature]
    Y = co2Data[depenFeature]
    n = len(Y)        
    sumX = sum(X)
    sumY = sum(Y)
    sumXY = sum(X[:] * Y[:])
    sumXsq = sum(X[:] * X[:])
    sumYsq = sum(Y[:] * Y[:])
    numerator = (n * sumXY) - (sumX * sumY)
    denominator = (n * sumXsq - (sumX ** 2)) * (n * sumYsq - (sumY ** 2))
    if denominator != 0:
        corr = numerator / math.sqrt(denominator)
    else:
        corr = None
    return corr

# %%
correlations = {"EngineSize-CO2Emissions": [], "Cylinders-CO2Emissions": [], "FuelConsumptionCity-CO2Emissions": []}
for feature in ["EngineSize", "Cylinders", "FuelConsumptionCity"]:
    corr = Karl_Pearson_Correlation(feature, "CO2Emissions")
    correlations[f"{feature}-CO2Emissions"].append(corr)
    correlations[f"{feature}-CO2Emissions"].append(corr ** 2)
pd.DataFrame(correlations, index = ['Correlation (r)', 'Goodness of Fit (r^2)'])
# Out:
#                        EngineSize-CO2Emissions  Cylinders-CO2Emissions  \
# Correlation (r)                       0.855194                0.834444
# Goodness of Fit (r^2)                 0.731356                0.696298
#
#                        FuelConsumptionCity-CO2Emissions
# Correlation (r)                                0.918415
# Goodness of Fit (r^2)                          0.843487

# %%
#confusion matrix for examining multicollinearity
columns = co2Data.drop(columns = ['Make', 'Model', 'VehicleClass'], axis = 1).columns.tolist()
corr = {"EngineSize": [], "Cylinders": [], "FuelConsumptionCity": [], "CO2Emissions": []}
for x in columns:
    for y in columns:
        corr[x].append(Karl_Pearson_Correlation(x, y))
confusionMatrix = pd.DataFrame(corr, index = columns)
confusionMatrix
# Out:
#                      EngineSize  Cylinders  FuelConsumptionCity  CO2Emissions
# EngineSize             1.000000   0.928464             0.834919      0.855194
# Cylinders              0.928464   1.000000             0.801500      0.834444
# FuelConsumptionCity    0.834919   0.801500             1.000000      0.918415
# CO2Emissions           0.855194   0.834444             0.918415      1.000000

# %% [markdown]
# ## <center> The Multiple Linear Regression </center>

# %% [markdown]
# ### ► Splitting the data into training and testing sets in an 80:20 ratio

# %%
n = int(len(co2Data) * 80/100)
indexForTrainingSet = random.sample(range(len(co2Data)), n)
print(f"the length of the sampled indices: {len(indexForTrainingSet)}")
print(f"Is duplicated? : {len(indexForTrainingSet) != len(set(indexForTrainingSet))}")
indexForTrainingSet[:10]
# Out:
# the length of the sampled indices: 4872
# Is duplicated? : False
# [3585, 3275, 5814, 5514, 408, 4300, 3805, 3398, 5412, 3]

# %%
print(f"Is this exactly 80%? : {len(indexForTrainingSet) == n}")
# Out:
# Is this exactly 80%? : True

# %%
trainingSet = {'Make': [], 'Model': [], 'VehicleClass': [], 'EngineSize': [], 'Cylinders': [], 'FuelConsumptionCity': [], 'CO2Emissions': []}
testingSet = {'Make': [], 'Model': [], 'VehicleClass': [], 'EngineSize': [], 'Cylinders': [], 'FuelConsumptionCity': [], 'CO2Emissions': []}
for index in range(len(co2Data)):
    if index in indexForTrainingSet:
        trainingSet['Make'].append(co2Data.iloc[index]['Make'])
        trainingSet['Model'].append(co2Data.iloc[index]['Model'])
        trainingSet['VehicleClass'].append(co2Data.iloc[index]['VehicleClass'])
        trainingSet['EngineSize'].append(co2Data.iloc[index]['EngineSize'])
        trainingSet['Cylinders'].append(co2Data.iloc[index]['Cylinders'])
        trainingSet['FuelConsumptionCity'].append(co2Data.iloc[index]['FuelConsumptionCity'])
        trainingSet['CO2Emissions'].append(co2Data.iloc[index]['CO2Emissions'])
    elif index not in indexForTrainingSet:
        testingSet['Make'].append(co2Data.iloc[index]['Make'])
        testingSet['Model'].append(co2Data.iloc[index]['Model'])
        testingSet['VehicleClass'].append(co2Data.iloc[index]['VehicleClass'])
        testingSet['EngineSize'].append(co2Data.iloc[index]['EngineSize'])
        testingSet['Cylinders'].append(co2Data.iloc[index]['Cylinders'])
        testingSet['FuelConsumptionCity'].append(co2Data.iloc[index]['FuelConsumptionCity'])
        testingSet['CO2Emissions'].append(co2Data.iloc[index]['CO2Emissions'])
trainingSet = pd.DataFrame(trainingSet).reset_index(drop = True)
testingSet = pd.DataFrame(testingSet).reset_index(drop = True)

# %%
print(f"the length of the training set: {len(trainingSet)}")
print(f"the length of the testing set: {len(testingSet)}")
print(f"the ratio of the training set to the entire dataset: {int((len(trainingSet) / len(co2Data)) * 100)}%")
print(f"the ratio of the testing set to the entire dataset: {int((len(testingSet) / len(co2Data)) * 100)}%")
# Out:
# the length of the training set: 4872
# the length of the testing set: 1218
# the ratio of the training set to the entire dataset: 80%
# the ratio of the testing set to the entire dataset: 20%

# %%
trainingSet[:5]
# Out:
#      Make   Model  VehicleClass  EngineSize  Cylinders  FuelConsumptionCity  \
# 0  221.08  200.29        218.04         2.0        4.0                  9.9
# 1  221.08  200.29        218.04         2.4        4.0                 11.2
# 2  221.08  138.00        218.04         1.5        4.0                  6.0
# 3  221.08  255.00        236.37         3.5        6.0                 12.7
# 4  221.08  243.75        236.37         3.5        6.0                 12.1
#
#    CO2Emissions
# 0         196.0
# 1         221.0
# 2         136.0
# 3         255.0
# 4         244.0

# %%
testingSet[:5]
# Out:
#      Make   Model  VehicleClass  EngineSize  Cylinders  FuelConsumptionCity  \
# 0  221.08  261.00        222.82         3.7        6.0                 13.4
# 1  221.08  225.33        218.04         2.4        4.0                 10.6
# 2  344.28  347.20        236.63         5.9       12.0                 18.0
# 3  252.80  213.78        218.04         2.0        4.0                 10.8
# 4  252.80  223.80        244.08         2.0        4.0                 11.5
#
#    CO2Emissions
# 0         267.0
# 1         212.0
# 2         359.0
# 3         214.0
# 4         230.0

# %% [markdown]
# ### ► Model training

# %% [markdown]
# #### ➔ Calculating Coefficients for Multiple Linear Regression Using Ordinary Least Squares

# %%
matrixX = trainingSet[['Make', 'Model', 'VehicleClass', 'EngineSize', 'Cylinders', 'FuelConsumptionCity']][:5]
ones = np.ones((matrixX.shape[0],1))
matrixX = np.hstack((ones, matrixX))

# %%
matrixX
# Out:
# array([[  1.  , 221.08, 200.29, 218.04,   2.  ,   4.  ,   9.9 ],
#        [  1.  , 221.08, 200.29, 218.04,   2.4 ,   4.  ,  11.2 ],
#        [  1.  , 221.08, 138.  , 218.04,   1.5 ,   4.  ,   6.  ],
#        [  1.  , 221.08, 255.  , 236.37,   3.5 ,   6.  ,  12.7 ],
#        [  1.  , 221.08, 243.75, 236.37,   3.5 ,   6.  ,  12.1 ]])

# %%
matrixY = np.matrix(trainingSet['CO2Emissions'][:5]).T

# %%
matrixY
# Out:
# matrix([[196.],
#         [221.],
#         [136.],
#         [255.],
#         [244.]])

# %%
matrixXTrans = matrixX.T
matrixXTrans
# Out:
# array([[  1.  ,   1.  ,   1.  ,   1.  ,   1.  ],
#        [221.08, 221.08, 221.08, 221.08, 221.08],
#        [200.29, 200.29, 138.  , 255.  , 243.75],
#        [218.04, 218.04, 218.04, 236.37, 236.37],
#        [  2.  ,   2.4 ,   1.5 ,   3.5 ,   3.5 ],
#        [  4.  ,   4.  ,   4.  ,   6.  ,   6.  ],
#        [  9.9 ,  11.2 ,   6.  ,  12.7 ,  12.1 ]])

# %%
matrix_XXT = np.matmul(matrixX, matrixXTrans)
matrix_XXT
# Out:
# array([[136652.9021, 136666.5721, 124137.228 , 151646.1612, 149386.9587],
#        [136666.5721, 136682.0921, 124145.628 , 151664.0712, 149404.0887],
#        [124137.228 , 124145.628 , 115517.058 , 135710.9312, 134154.8312],
#        [151646.1612, 151664.0712, 135710.9312, 169982.6833, 167106.3133],
#        [149386.9587, 149404.0887, 134154.8312, 167106.3133, 164356.8658]])

# %% [markdown]
# ## <center> ......  Still on Developing ........... </center>
